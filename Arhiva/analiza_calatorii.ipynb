# %%
#verifican
print("--- Primele randuri ale setului de date ---")
display(df.head())

print("\n--- Informatii despre tipurile de date ---")
df.info()
# Out:
# --- Primele randuri ale setului de date ---
#    Trip ID       Destination Start date   End date  Duration (days)  \
# 0        1        London, UK   5/1/2023   5/8/2023              7.0
# 1        2  Phuket, Thailand  6/15/2023  6/20/2023              5.0
# 2        3   Bali, Indonesia   7/1/2023   7/8/2023              7.0
# 3        4     New York, USA  8/15/2023  8/29/2023             14.0
# 4        5      Tokyo, Japan  9/10/2023  9/17/2023              7.0
#
#    Traveler name  Traveler age Traveler gender Traveler nationality  \
# 0     John Smith          35.0            Male             American
# 1       Jane Doe          28.0          Female             Canadian
# 2      David Lee          45.0            Male               Korean
# 3  Sarah Johnson          29.0          Female              British
# 4     Kim Nguyen          26.0          Female           Vietnamese
#
#   Accommodation type Accommodation cost Transportation type  \
# ...

# %%
#verif daca am valori lipsa
print("Valori lipsa per coloana:\n", df.isnull().sum())

#transformam in numere costurile
#daca sunt $, errors='coerce' le va face NaN, apoi le putem umple cu 0 sau media
df['Accommodation cost'] = pd.to_numeric(df['Accommodation cost'], errors='coerce')
df['Transportation cost'] = pd.to_numeric(df['Transportation cost'], errors='coerce')

#sterg randurile care au ramas goale dupa conversie
df = df.dropna()

print("\nDatele au fost curatate!")
# Out:
# Valori lipsa per coloana:
#  Trip ID                 0
# Destination             2
# Start date              2
# End date                2
# Duration (days)         2
# Traveler name           2
# Traveler age            2
# Traveler gender         2
# Traveler nationality    2
# Accommodation type      2
# Accommodation cost      2
# Transportation type     3
# Transportation cost     3
# dtype: int64
#
# Datele au fost curatate!

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Transportation type', data=df, palette='viridis')
plt.title('Preferintele de transport ale turistilor')
plt.show()
# Out:
# C:\Users\Laura\AppData\Local\Temp\ipykernel_186496\676490089.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Transportation type', data=df, palette='viridis')
